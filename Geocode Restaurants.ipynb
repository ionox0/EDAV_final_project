# %%
from geopy.geocoders import Nominatim

# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Michael\Anaconda\lib\site-packages\pandas\computation\__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
data = pd.read_csv("Bar_Address.csv")

# %%
data.head()
# Out:
#                     Address                       Name CUISINE DESCRIPTION
# 0    1 7 AVENUE SOUTH 10014  ayza wine & chocolate bar              French
# 1         1 E 55TH ST 10022               the polo bar            American
# 2  1 EAST  161 STREET 10451        stand 334 beer room            American
# 3  1 EAST  161 STREET 10451     mohegan sun sports bar            American
# 4         1 JFK INTEL 11430  sammy's beach bar & grill            American

# %%
geolocator = Nominatim()

# %%
for i in xrange(1200,1505):
    location.append(geolocator.geocode(data['Address'][i]))

# %%
print location.longitude, location.latitude
# Out:
# -82.5583439 27.559756

# %%
for i in xrange(0,len(location)):
    if location[i] == None:
        location.remove(location[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-71-8eb874430d0b> in <module>()
#       1 for i in xrange(0,len(location)):
# ----> 2     if location[i] == None:
#       3         location.remove(location[i])
#
# IndexError: list index out of range

# %%
new_loc = []
for i in xrange(0,len(location)):
    new_loc.append(location[i][1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-77e10106e4bd> in <module>()
#       1 new_loc = []
#       2 for i in xrange(0,len(location)):
# ----> 3     new_loc.append(location[i][1])
#
# TypeError: 'NoneType' object has no attribute '__getitem__'

# %%
len(location)
# Out:
# 1176

# %%
new_loc
# Out:
# [(40.059499, -85.6754779),
#  (40.72064, -74.0049699),
#  (39.747886, -86.1783219),
#  (40.7685324, -73.9827662),
#  (40.74732695, -73.9864515104169),
#  (40.7655395, -73.9766657109636),
#  (40.639137, -73.9685419462281),
#  (40.5782018, -73.9593925),
#  (40.6392004, -73.9684005610696),
#  (40.6976869, -73.8595701),
#  (40.7443681, -73.9920655),
#  (40.8032214, -73.9639172),
#  (40.7709956363636, -73.9619141818182),
#  (40.7584646, -73.849272),
#  (40.6925207, -73.8590856),
#  (40.6098107, -73.962628),
#  (40.8484038, -73.8551974),
#  (40.57343415, -73.9789896895267),
#  (40.73397215, -73.9551308143722),
#  (40.828225, -73.850067),
#  (40.74215055, -73.982527825845),
#  (40.7112037, -73.855558),
#  (40.7343237, -73.955094),
#  (40.7568655, -73.8389225),
#  (40.6925207, -73.8590856),
#  (40.7568655, -73.8389225),
#  (40.678577, -73.8679279),
#  (40.7584646, -73.849272),
#  (40.685645, -73.9152899),
#  (-26.0640174, 28.0618453),
#  (40.633866, -74.1356384638648),
# ...

# %%
import csv
with open('test.csv', 'wb') as csvfile:
    writer = csv.writer(csvfile, delimiter=' ', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for i in xrange(0,len(new_loc)):
        writer.writerow(new_loc[i])
